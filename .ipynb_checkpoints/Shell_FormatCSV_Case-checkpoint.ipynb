# %%
# latest update
# June 27, 2017
# Changes done by: Jimmy Vivas

# This code was developed by Jimmy Vivas for Aspen Technology
# For Shell case, they created one file per month and a folder per tag

# The code will take all files within sub folders but it wont process files located in the root folder
# The colde will take the file name as a tagname and look for that tagname in a tag dictionary file
# Then it will add the tagname and tag description to the CSV file for each file wihtin sub folders
# The code will merge all individual csv files (monthly files) to be one single file

# %%
from os import listdir
from os import walk
import pandas as pd
import math
import numpy as np

# %%
# mac Path
#CSVPath1 =  '/Users/jvivas/Documents/XMT Baytwon Sensor Data' \
#            '/Sensor Data/Testing'

CSVPath1 = '/Users/jvivas/Documents/Aspen/Shell/to be processed'
CSVMetaDataFile = '/Users/jvivas/Documents/Aspen/Shell/Metadata/Data Dictionary.csv'
CSVPathProcessed = '/Users/jvivas/Documents/Aspen/Shell/Processed'

# Windows Path
# CSVPath1 = 'C:/Users/jvivas/Dropbox/Mtell Customer Projects/XOM BayTown RHC MEA Tower Foaming/Sensor Data/' \
#           'To be Processed'

# CSVPath1 = 'C:/Mtell/Projects/XOM Baytown POC/Sensor Data/ToBeFormatted'

# %%
def GetFiles(CSVPath):
    CSVFileList = []
    NanPHDTagList = []
    CSVFileListAll = listdir(CSVPath)

    m = len(CSVFileListAll)

    for i in range(m):
        fileNameStr = CSVFileListAll[i]
        fileStr = fileNameStr.split('.')[0]
        fileExt = fileNameStr.split('.')[1]
        if fileExt == "csv":
            CSVFileList.append(fileNameStr)

    n = len(CSVFileList)
    return(n, CSVFileList)

# %% [markdown]
# # Uncomment following cell for debugging purposes

# %%
# pd.set_option('display.max_rows', 500)
# pd.set_option('display.max_columns', 500)
# np.set_printoptions(threshold=np.nan)

# %%
def LoadCSV(FileAndPath, file):
    print ('Loading ' + file)
    df2 = pd.read_csv(FileAndPath+'/'+file, low_memory=False)
    return(df2)

# %%
def GetTagName(CSVFileName):
    IndexStr = CSVFileName.replace('_', 'OK', 2).find('_') - 2
    TagName = CSVFileName[: IndexStr]
    return(TagName)

# %% [markdown]
# # This is the Main Code to execute

# %%
print ('Loading Tagname Metadata')
TagMetaDataDF = pd.read_csv(CSVMetaDataFile, low_memory=False)

FolderList = next(walk(CSVPath1))[1]
FolderListNumber = len(FolderList)

for j in range(FolderListNumber):
    CSVFinalPath = CSVPath1 + '/' + FolderList[j]
    
    print ('Getting files within folder: ' + FolderList[j])
    n, CSVFileList = GetFiles(CSVFinalPath)

    i = 0
    for i in range(n - 1):
        CSVFile = CSVFileList[i]
        # CSVFileWithPath = CSVPath1 + "/" + CSVFileList[i]

        df2 = LoadCSV(CSVFinalPath, CSVFile)
        print ('Getting TagName')
        TagName =  GetTagName(CSVFile)
        print('Getting TagDescription')
        TagDescription = TagMetaDataDF.loc[TagMetaDataDF['Tag Name'] == TagName, 'Description'].values[0]
        print ('Adding Tag name and description to CSV file')

        df2['TagName'] = TagName
        df2['Description'] = TagDescription

        df2.to_csv(CSVPathProcessed + '/' + str(CSVFile.replace('.csv', '')) + '_Formatted.csv', index=False)
        df2_concatenated = df2.append(df2)
    df2_concatenated.to_csv(CSVPathProcessed + '/' + str(CSVFile.replace('.csv', '')) + '_Concatenated.csv', index=False)
    print ('Tagname: ' + TagName + ' Processed')
# Out:
# Loading Tagname Metadata
# Getting files within folder: tag_1001_39
# Loading tag_1001_39_2013_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2013_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2013_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2013_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2013_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2013_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2013_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2013_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2013_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2013_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2013_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2013_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2014_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2014_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2014_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2014_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2014_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2014_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2014_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2014_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2014_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2014_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2014_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2014_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2015_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2015_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2015_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2015_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2015_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2015_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2015_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2015_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2015_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2015_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2015_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2015_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2016_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1001_39_2016_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Tagname: tag_1001_39 Processed
# Getting files within folder: tag_1002_18
# Loading tag_1002_18_2013_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2013_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2013_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2013_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2013_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2013_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2013_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2013_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2013_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2013_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2013_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2013_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2014_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2014_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2014_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2014_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2014_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2014_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2014_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2014_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2014_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2014_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2014_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2014_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2015_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2015_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2015_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2015_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2015_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2015_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2015_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2015_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2015_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2015_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2015_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2015_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2016_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1002_18_2016_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Tagname: tag_1002_18 Processed
# Getting files within folder: tag_1006_2
# Loading tag_1006_2_2013_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2013_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2013_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2013_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2013_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2013_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2013_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2013_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2013_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2013_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2013_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2013_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2014_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2014_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2014_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2014_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2014_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2014_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2014_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2014_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2014_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2014_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2014_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2014_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2015_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2015_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2015_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2015_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2015_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2015_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2015_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2015_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2015_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2015_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2015_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2015_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2016_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1006_2_2016_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Tagname: tag_1006_2 Processed
# Getting files within folder: tag_1007_3
# Loading tag_1007_3_2013_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2013_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2013_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2013_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2013_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2013_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2013_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2013_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2013_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2013_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2013_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2013_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2014_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2014_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2014_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2014_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2014_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2014_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2014_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2014_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2014_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2014_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2014_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2014_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2015_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2015_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2015_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2015_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2015_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2015_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2015_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2015_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2015_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2015_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2015_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2015_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2016_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1007_3_2016_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Tagname: tag_1007_3 Processed
# Getting files within folder: tag_1008_4
# Loading tag_1008_4_2013_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2013_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2013_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2013_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2013_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2013_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2013_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2013_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2013_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2013_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2013_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2013_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2014_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2014_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2014_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2014_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2014_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2014_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2014_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2014_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2014_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2014_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2014_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2014_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2015_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2015_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2015_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2015_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2015_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2015_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2015_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2015_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2015_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2015_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2015_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2015_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2016_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1008_4_2016_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Tagname: tag_1008_4 Processed
# Getting files within folder: tag_1009_5
# Loading tag_1009_5_2013_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2013_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2013_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2013_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2013_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2013_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2013_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2013_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2013_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2013_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2013_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2013_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2014_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2014_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2014_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2014_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2014_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2014_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2014_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2014_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2014_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2014_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2014_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2014_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2015_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2015_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2015_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2015_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2015_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2015_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2015_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2015_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2015_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2015_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2015_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2015_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2016_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1009_5_2016_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Tagname: tag_1009_5 Processed
# Getting files within folder: tag_1010_8
# Loading tag_1010_8_2013_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2013_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2013_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2013_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2013_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2013_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2013_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2013_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2013_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2013_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2013_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2013_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2014_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2014_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2014_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2014_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2014_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2014_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2014_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2014_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2014_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2014_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2014_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2014_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2015_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2015_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2015_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2015_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2015_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2015_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2015_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2015_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2015_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2015_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2015_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2015_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2016_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1010_8_2016_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Tagname: tag_1010_8 Processed
# Getting files within folder: tag_1011_9
# Loading tag_1011_9_2013_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2013_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2013_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2013_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2013_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2013_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2013_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2013_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2013_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2013_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2013_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2013_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2014_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2014_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2014_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2014_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2014_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2014_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2014_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2014_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2014_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2014_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2014_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2014_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2015_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2015_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2015_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2015_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2015_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2015_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2015_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2015_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2015_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2015_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2015_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2015_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2016_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1011_9_2016_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Tagname: tag_1011_9 Processed
# Getting files within folder: tag_1012_11
# Loading tag_1012_11_2013_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2013_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2013_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2013_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2013_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2013_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2013_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2013_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2013_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2013_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2013_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2013_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2014_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2014_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2014_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2014_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2014_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2014_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2014_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2014_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2014_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2014_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2014_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2014_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2015_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2015_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2015_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2015_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2015_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2015_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2015_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2015_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2015_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2015_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2015_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2015_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2016_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1012_11_2016_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Tagname: tag_1012_11 Processed
# Getting files within folder: tag_1013_12
# Loading tag_1013_12_2013_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2013_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2013_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2013_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2013_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2013_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2013_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2013_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2013_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2013_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2013_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2013_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2014_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2014_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2014_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2014_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2014_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2014_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2014_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2014_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2014_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2014_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2014_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2014_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2015_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2015_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2015_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2015_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2015_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2015_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2015_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2015_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2015_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2015_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2015_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2015_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2016_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1013_12_2016_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Tagname: tag_1013_12 Processed
# Getting files within folder: tag_1014_17
# Loading tag_1014_17_2013_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2013_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2013_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2013_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2013_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2013_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2013_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2013_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2013_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2013_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2013_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2013_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2014_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2014_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2014_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2014_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2014_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2014_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2014_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2014_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2014_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2014_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2014_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2014_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2015_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2015_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2015_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2015_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2015_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2015_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2015_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1014_17_2015_M5.csv
# Getting TagName
# Getting TagDescription
# ...
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2014_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2014_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2014_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2014_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2014_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2014_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2014_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2014_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2015_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2015_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2015_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2015_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2015_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2015_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2015_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2015_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2015_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2015_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2015_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2015_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2016_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1061_73_2016_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Tagname: tag_1061_73 Processed
# Getting files within folder: tag_1062_48
# Loading tag_1062_48_2013_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2013_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2013_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2013_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2013_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2013_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2013_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2013_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2013_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2013_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2013_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2013_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2014_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2014_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2014_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2014_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2014_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2014_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2014_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2014_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2014_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2014_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2014_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2014_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2015_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2015_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2015_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2015_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2015_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2015_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2015_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2015_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2015_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2015_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2015_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2015_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2016_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1062_48_2016_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Tagname: tag_1062_48 Processed
# Getting files within folder: tag_1063_49
# Loading tag_1063_49_2013_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2013_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2013_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2013_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2013_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2013_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2013_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2013_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2013_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2013_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2013_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2013_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2014_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2014_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2014_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2014_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2014_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2014_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2014_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2014_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2014_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2014_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2014_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2014_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2015_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2015_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2015_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2015_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2015_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2015_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2015_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2015_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2015_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2015_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2015_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2015_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2016_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1063_49_2016_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Tagname: tag_1063_49 Processed
# Getting files within folder: tag_1064_47
# Loading tag_1064_47_2013_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2013_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2013_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2013_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2013_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2013_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2013_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2013_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2013_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2013_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2013_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2013_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2014_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2014_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2014_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2014_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2014_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2014_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2014_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2014_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2014_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2014_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2014_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2014_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2015_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2015_M10.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2015_M11.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2015_M12.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2015_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2015_M3.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2015_M4.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2015_M5.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2015_M6.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2015_M7.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2015_M8.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2015_M9.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2016_M1.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Loading tag_1064_47_2016_M2.csv
# Getting TagName
# Getting TagDescription
# Adding Tag name and description to CSV file
# Tagname: tag_1064_47 Processed
